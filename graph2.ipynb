# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("./datos2.csv")
df.tail()
# Out:
#     inversion  displacement  exchange  insertion  inverted_displacement  \
# 95        143           154       143        145                    145
# 96        143           145       143        145                    145
# 97        143           155       144        145                    145
# 98        143           145       144        145                    145
# 99        143           144       144        145                    145
#
#     inverted_exchange
# 95                145
# 96                148
# 97                146
# 98                144
# 99                143

# %%
plt.plot(df['inversion'], label='Inversion')
plt.plot(df['displacement'], label='Displacement')
plt.plot(df['exchange'], label='Exchange')
plt.plot(df['insertion'], label='Insertion')
plt.plot(df['inverted_exchange'], label='Inverted Exchange')
plt.plot(df['inverted_displacement'], label='Inverted Displacement')
plt.ylabel('Distancia mínima en Km')
plt.xlabel('Generaciones')
plt.title('Rendimiento de algoritmos géneticos')
plt.legend()
